# %% [markdown]
# # STELLAR CLASSIFICATION

# %% [markdown]
# # **Bối cảnh**

# %% [markdown]
# Trong thiên văn học, phân loại sao là phân loại các ngôi sao dựa trên đặc điểm quang phổ của chúng. Sơ đồ phân loại các thiên hà, chuẩn tinh và sao là một trong những sơ đồ cơ bản nhất trong thiên văn học. Việc phân loại sớm các ngôi sao và sự phân bố của chúng trên bầu trời đã dẫn đến sự hiểu biết rằng chúng tạo nên thiên hà của chúng ta và, sau sự khác biệt rằng Andromeda là một thiên hà riêng biệt với thiên hà của chúng ta, nhiều thiên hà bắt đầu được khảo sát khi các kính thiên văn mạnh hơn được chế tạo . Dữ liệu này nhằm mục đích phân loại các ngôi sao, thiên hà và chuẩn tinh dựa trên đặc điểm quang phổ của chúng.

# %% [markdown]
# # **Nội dung**

# %% [markdown]
# Dữ liệu bao gồm 100.000 quan sát không gian được thực hiện bởi SDSS (Khảo sát bầu trời kỹ thuật số Sloan). Mỗi quan sát được mô tả bằng 17 cột đặc trưng và 1 cột *class* xác định nó là *một ngôi sao, thiên hà hoặc chuẩn tinh*.
#
# **obj_ID** = Mã định danh đối tượng, giá trị duy nhất nhận dạng đối tượng trong danh mục hình ảnh được CAS sử dụng*
#
# **alpha** = Góc thăng thiên phải (tại kỷ nguyên J2000)*
#
# **delta** = Góc lệch (tại kỷ nguyên J2000)*
#
# **u** = Bộ lọc tia cực tím trong hệ thống trắc quang
#
# **g** = Bộ lọc màu xanh lá cây trong hệ thống trắc quang
#
# **r** = Bộ lọc màu đỏ trong hệ thống trắc quang
#
# **i** = Bộ lọc cận hồng ngoại trong hệ thống trắc quang
#
# **z** = Bộ lọc hồng ngoại trong hệ thống trắc quang
#
# **run_ID** = Số lần chạy được sử dụng để xác định lần quét cụ thể*
#
# **rereun_ID** = Số chạy lại để chỉ định hình ảnh được xử lý như thế nào*
#
# **cam_col** = Cột camera để xác định đường quét trong quá trình chạy*
#
# **field_ID** = Số trường để xác định từng trường*
#
# **spec_obj_ID** = ID duy nhất được sử dụng cho các đối tượng quang phổ quang học (điều này có nghĩa là 2 quan sát khác nhau có cùng **spec_obj_ID** phải chia sẻ lớp đầu ra)
#
# **class** = lớp đối tượng (thiên hà, sao hoặc chuẩn tinh)
#
# **redshift** = giá trị dịch chuyển đỏ dựa trên sự gia tăng bước sóng
#
# **plate** = tấm ID, xác định từng tấm trong SDSS
#
# **MJD** = Ngày Julian đã sửa đổi, được sử dụng để biểu thị thời điểm một phần
# SDSS nhất định dữ liệu được lấy
#
# **Fiber_ID** = ID sợi xác định sợi hướng ánh sáng vào mặt phẳng tiêu điểm trong mỗi quan sát*

# %% [markdown]
# # **Thuật toán được sử dụng trong bài:**
# 1.   K-Nearest Neighbors (KNN)
# 2.   Decision Tree
# 3.   Gaussian Naive Bayes (GaussianNB)
# 4.   Random Forest

# %% [markdown]
# # **Khai báo thư viện:**

# %% [markdown]
# **- pandas** dùng để tải tập dữ liệu
#
# **- numpy** dùng để trình diễn các phép toán trên tập dữ liệu
#
# **- matplotlib.pyplot** trực quan hóa các thuộc tính của dữ liệu dưới dạng biểu đồ.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier,plot_tree
# Warning ignore libraries to be added

# %%
from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# ---
# ---
# <br>

# %% [markdown]
# # **Tạo khung dữ liệu:**

# %%
df=pd.read_csv('/content/star_classification.csv')
df.head()
# Out:
#          obj_ID       alpha      delta         u         g         r  \
# 0  1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1  1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2  1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3  1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4  1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
#
#           i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0  19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1  21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2  19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3  20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4  15.97711  15.54461    8102       301        3       137  6.891865e+18
#
#     class  redshift  plate    MJD  fiber_ID
# 0  GALAXY  0.634794   5812  56354       171
# 1  GALAXY  0.779136  10445  58158       427
# 2  GALAXY  0.644195   4576  55592       299
# 3  GALAXY  0.932346   9149  58039       775
# 4  GALAXY  0.116123   6121  56187       842

# %%
#Đổi tên các cột có trong Dataset
df.rename(columns={'u': 'Ultraviolet_Filter',
                   'g': 'Green_Filter',
                   'r': 'Red_Filter',
                   'i': 'NearInfrared_Filter',
                   'z': 'Infrared_Filter'}
                                , inplace=True)

# %%
df.shape
# Out:
# (100000, 18)

# %%
df.columns
# Out:
# Index(['obj_ID', 'alpha', 'delta', 'Ultraviolet_Filter', 'Green_Filter',
#        'Red_Filter', 'NearInfrared_Filter', 'Infrared_Filter', 'run_ID',
#        'rerun_ID', 'cam_col', 'field_ID', 'spec_obj_ID', 'class', 'redshift',
#        'plate', 'MJD', 'fiber_ID'],
#       dtype='object')

# %% [markdown]
# ---
# <br>

# %% [markdown]
# # **1.   Tiền xử lí dữ liệu**

# %% [markdown]
# # **Phân tích dữ liệu thăm dò(Exploratory Data Analysis):**

# %%
#Kiểm tra giá trị còn thiếu trong Dataset
df.isnull().sum()
# Out:
# obj_ID                 0
# alpha                  0
# delta                  0
# Ultraviolet_Filter     0
# Green_Filter           0
# Red_Filter             0
# NearInfrared_Filter    0
# Infrared_Filter        0
# run_ID                 0
# rerun_ID               0
# cam_col                0
# field_ID               0
# spec_obj_ID            0
# class                  0
# redshift               0
# plate                  0
# MJD                    0
# fiber_ID               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   obj_ID               100000 non-null  float64
#  1   alpha                100000 non-null  float64
#  2   delta                100000 non-null  float64
#  3   Ultraviolet_Filter   100000 non-null  float64
#  4   Green_Filter         100000 non-null  float64
#  5   Red_Filter           100000 non-null  float64
#  6   NearInfrared_Filter  100000 non-null  float64
#  7   Infrared_Filter      100000 non-null  float64
#  8   run_ID               100000 non-null  int64
#  9   rerun_ID             100000 non-null  int64
#  10  cam_col              100000 non-null  int64
#  11  field_ID             100000 non-null  int64
#  12  spec_obj_ID          100000 non-null  float64
#  13  class                100000 non-null  object
#  14  redshift             100000 non-null  float64
#  15  plate                100000 non-null  int64
#  16  MJD                  100000 non-null  int64
#  17  fiber_ID             100000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 13.7+ MB

# %% [markdown]
# **Thuộc tính mục tiêu 'class' không thuộc kiểu dữ liệu số học, do đó ta cần phải mã hóa nó.**

# %%
#Tính các số liệu cơ bản(trung bình, trung vị, độ lệch chuẩn...)
df.describe()
# Out:
#              obj_ID          alpha          delta  Ultraviolet_Filter  \
# count  1.000000e+05  100000.000000  100000.000000       100000.000000
# mean   1.237665e+18     177.629117      24.135305           21.980468
# std    8.438560e+12      96.502241      19.644665           31.769291
# min    1.237646e+18       0.005528     -18.785328        -9999.000000
# 25%    1.237659e+18     127.518222       5.146771           20.352353
# 50%    1.237663e+18     180.900700      23.645922           22.179135
# 75%    1.237668e+18     233.895005      39.901550           23.687440
# max    1.237681e+18     359.999810      83.000519           32.781390
#
#         Green_Filter     Red_Filter  NearInfrared_Filter  Infrared_Filter  \
# count  100000.000000  100000.000000        100000.000000    100000.000000
# mean       20.531387      19.645762            19.084854        18.668810
# std        31.750292       1.854760             1.757895        31.728152
# min     -9999.000000       9.822070             9.469903     -9999.000000
# 25%        18.965230      18.135828            17.732285        17.460677
# 50%        21.099835      20.125290            19.405145        19.004595
# 75%        22.123767      21.044785            20.396495        19.921120
# max        31.602240      29.571860            32.141470        29.383740
#
#               run_ID  rerun_ID        cam_col       field_ID   spec_obj_ID  \
# count  100000.000000  100000.0  100000.000000  100000.000000  1.000000e+05
# mean     4481.366060     301.0       3.511610     186.130520  5.783882e+18
# std      1964.764593       0.0       1.586912     149.011073  3.324016e+18
# min       109.000000     301.0       1.000000      11.000000  2.995191e+17
# 25%      3187.000000     301.0       2.000000      82.000000  2.844138e+18
# 50%      4188.000000     301.0       4.000000     146.000000  5.614883e+18
# 75%      5326.000000     301.0       5.000000     241.000000  8.332144e+18
# max      8162.000000     301.0       6.000000     989.000000  1.412694e+19
#
#             redshift          plate            MJD       fiber_ID
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.576661    5137.009660   55588.647500     449.312740
# std         0.730707    2952.303351    1808.484233     272.498404
# min        -0.009971     266.000000   51608.000000       1.000000
# 25%         0.054517    2526.000000   54234.000000     221.000000
# 50%         0.424173    4987.000000   55868.500000     433.000000
# 75%         0.704154    7400.250000   56777.000000     645.000000
# max         7.011245   12547.000000   58932.000000    1000.000000

# %%
df['class'].nunique()
# Out:
# 3

# %%
df['class'].unique()
# Out:
# array(['GALAXY', 'QSO', 'STAR'], dtype=object)

# %% [markdown]
# *   ***Galaxy:*** A galaxy is a system of stars, stellar remnants, interstellar gas, dust, dark matter, bound together by gravity.[1][2] The word is derived from the Greek galaxias (γαλαξίας), literally 'milky', a reference to the Milky Way galaxy that contains the Solar System. Galaxies, averaging an estimated 100 million stars,[3] range in size from dwarfs with less than a hundred million stars, to the largest galaxies known – supergiants with one hundred trillion stars,[4] each orbiting its galaxy's center of mass. Most of the mass in a typical galaxy is in the form of dark matter, with only a few percent of that mass visible in the form of stars and nebulae. Supermassive black holes are a common feature at the centres of galaxies.
# *   ***Star:*** A star's life begins with the gravitational collapse of a gaseous nebula of material composed primarily of hydrogen, along with helium and trace amounts of heavier elements. Its total mass is the main factor determining its evolution and eventual fate. A star shines for most of its active life due to the thermonuclear fusion of hydrogen into helium in its core. This process releases energy that traverses the star's interior and radiates into outer space. At the end of a star's lifetime, its core becomes a stellar remnant: a white dwarf, a neutron star, or—if it is sufficiently massive—a black hole.
# *   ***Quasars:*** A quasar is an extremely luminous active galactic nucleus (AGN). It is pronounced /ˈkweɪzɑːr/ KWAY-zar, and sometimes known as a quasi-stellar object, abbreviated QSO. This emission from an AGN is powered by a supermassive black hole with a mass ranging from millions to tens of billions of solar masses, surrounded by a gaseous accretion disc. Gas in the disc falling towards the black hole heats up because of friction and releases energy in the form of electromagnetic radiation. The radiant energy of quasars is enormous; the most powerful quasars have luminosities thousands of times greater than that of a galaxy such as the Milky Way.

# %% [markdown]
# ---

# %% [markdown]
# *   ***Galaxy:*** Thiên hà là một hệ thống các ngôi sao, tàn dư của sao, khí liên sao, bụi, vật chất tối, liên kết với nhau bằng lực hấp dẫn.[1] [2] Từ này có nguồn gốc từ tiếng Hy Lạp galaxias (γαλαξίας), nghĩa đen là 'sữa', ám chỉ đến thiên hà Dải Ngân hà chứa Hệ Mặt trời. Các thiên hà, có trung bình khoảng 100 triệu ngôi sao,[3] có kích thước từ các thiên hà lùn có ít hơn một trăm triệu sao, đến các thiên hà lớn nhất được biết đến – các siêu khổng lồ với một trăm nghìn tỷ ngôi sao,[4] mỗi thiên hà quay quanh tâm khối lượng của thiên hà. Phần lớn khối lượng trong một thiên hà điển hình ở dạng vật chất tối, chỉ một vài phần trăm khối lượng đó có thể nhìn thấy được ở dạng sao và tinh vân. Lỗ đen siêu lớn là đặc điểm chung ở trung tâm các thiên hà.
# *   ***Star:*** Cuộc sống của một ngôi sao bắt đầu bằng sự suy sụp hấp dẫn của một tinh vân khí chứa vật chất chủ yếu là hydro, cùng với heli và một lượng nhỏ các nguyên tố nặng hơn. Tổng khối lượng của nó là yếu tố chính quyết định sự tiến hóa và số phận cuối cùng của nó. Một ngôi sao tỏa sáng trong phần lớn thời gian hoạt động của nó nhờ phản ứng tổng hợp nhiệt hạch của hydro thành heli trong lõi của nó. Quá trình này giải phóng năng lượng đi qua bên trong ngôi sao và tỏa ra không gian bên ngoài. Vào cuối vòng đời của một ngôi sao, lõi của nó trở thành tàn dư của sao: sao lùn trắng, sao neutron, hoặc—nếu nó đủ lớn—một lỗ đen.
# *   ***Quasars:*** Chuẩn tinh(Quasars) là một nhân thiên hà hoạt động cực kỳ sáng (AGN). Nó được phát âm là /ˈkweɪzɑːr/ KWAY-zar, và đôi khi được biết đến như một vật thể tựa sao, viết tắt là QSO. Sự phát xạ từ AGN này được cung cấp bởi một lỗ đen siêu lớn với khối lượng từ hàng triệu đến hàng chục tỷ lần khối lượng mặt trời, được bao quanh bởi một đĩa bồi tụ khí. Khí trong đĩa rơi về phía lỗ đen nóng lên do ma sát và giải phóng năng lượng dưới dạng bức xạ điện từ. Năng lượng bức xạ của chuẩn tinh là rất lớn; các chuẩn tinh mạnh nhất có độ sáng lớn hơn hàng nghìn lần so với độ sáng của một thiên hà như Dải Ngân hà.

# %%
df['class'].value_counts()
# Out:
# GALAXY    59445
# STAR      21594
# QSO       18961
# Name: class, dtype: int64

# %% [markdown]
# **Tập dữ liệu ứng với thuộc tính mục tiêu bị mất cân bằng, cần phải cân bằng lại thông qua kĩ thuật Resampling**

# %% [markdown]
# ---
# ---
# <br>

# %% [markdown]
# # **Trực quan hóa dữ liệu(Data Visualization):**

# %%
#định dạng cho biểu đồ
sns.set(style='darkgrid', palette='dark')

# %%
sns.countplot(x = df['class'])
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của alpha
sns.distplot(df['alpha'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của delta
sns.distplot(df['delta'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của Ultraviolet_Filter
sns.distplot(df['Ultraviolet_Filter'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của Green_Filter
sns.distplot(df['Green_Filter'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của Red_Filter
sns.distplot(df['Red_Filter'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của NearInfrared_Filter
sns.distplot(df['NearInfrared_Filter'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của Infrared_Filter
sns.distplot(df['Infrared_Filter'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của run_ID
sns.distplot(df['run_ID'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của rereun_ID
sns.distplot(df['rerun_ID'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của cam_col
sns.distplot(df['cam_col'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của feild_ID
sns.distplot(df['field_ID'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của spec_obj_ID
sns.distplot(df['spec_obj_ID'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của MJD
sns.distplot(df['MJD'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của fiber_ID
sns.distplot(df['fiber_ID'], color="midnightblue")
plt.show()

# %%
#Biểu đồ phân phối dữ liệu của redshift
sns.distplot(df.redshift, color="midnightblue")
# Out:
# <Axes: xlabel='redshift', ylabel='Density'>

# %%
#Biểu đồ phân phối dữ liệu của plate
sns.distplot(df.plate, color="midnightblue")
# Out:
# <Axes: xlabel='plate', ylabel='Density'>

# %%
sns.scatterplot(x = df.alpha, y = df.delta, color="midnightblue")
plt.show()

# %%
#Display histograms of Numerical Columns
#.hist(): function in Pandas generates separate histograms for each numerical column, providing a visual
# representation of the distribution of values within those columns
df.hist(bins =25 , figsize= (14,14), color="midnightblue")
plt.show()

# %%
# Heatmap for expressing correlation
#Correlation Matrix(Ma trận tương quan)

fig,ax=plt.subplots(1,1,figsize=(20,12))
sns.heatmap(df.corr(),annot=True,cmap="PuBu",linewidths=1)
plt.show()

# %% [markdown]
# ---
# <br>

# %% [markdown]
# # **Mã hóa(Encoding):**

# %%
# We can either do this, which doesn't involve encoding or we can perform encoding

# Assigning a new value to the 'class' column by using map
#df['class']=df['class'].map({'GALAXY':1,'STAR':0,'QSO':2})
# OR
# we can encode the data

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
#{'GALAXY':0,'STAR':2,'QSO':1}
df['class'] = LE.fit_transform(df['class'])

# %%
df['class'].value_counts()
# Out:
# 0    59445
# 2    21594
# 1    18961
# Name: class, dtype: int64

# %% [markdown]
# ---
# ---
# <br>

# %% [markdown]
# # **Lựa chọn tính năng(Feature Selection):**

# %%
X = df[['Ultraviolet_Filter', 'Green_Filter','Red_Filter', 'NearInfrared_Filter', 'Infrared_Filter', 'redshift', 'plate']]
X
# Out:
#        Ultraviolet_Filter  Green_Filter  Red_Filter  NearInfrared_Filter  \
# 0                23.87882      22.27530    20.39501             19.16573
# 1                24.77759      22.83188    22.58444             21.16812
# 2                25.26307      22.66389    20.60976             19.34857
# 3                22.13682      23.77656    21.61162             20.50454
# 4                19.43718      17.58028    16.49747             15.97711
# ...                   ...           ...         ...                  ...
# 99995            22.16759      22.97586    21.90404             21.30548
# 99996            22.69118      22.38628    20.45003             19.75759
# 99997            21.16916      19.26997    18.20428             17.69034
# 99998            25.35039      21.63757    19.91386             19.07254
# 99999            22.62171      21.79745    20.60115             20.00959
#
#        Infrared_Filter  redshift  plate
# 0             18.79371  0.634794   5812
# 1             21.61427  0.779136  10445
# 2             18.94827  0.644195   4576
# 3             19.25010  0.932346   9149
# 4             15.54461  0.116123   6121
# ...                ...       ...    ...
# 99995         20.73569  0.000000   9374
# 99996         19.41526  0.404895   7626
# 99997         17.35221  0.143366   2764
# 99998         18.62482  0.455040   6751
# 99999         19.28075  0.542944   7410
#
# [100000 rows x 7 columns]

# %%
y = df['class']
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: class, Length: 100000, dtype: int64

# %% [markdown]
# ---
# ---
# <br>

# %% [markdown]
# # Resampling

# %%
#Vì dữ liệu của các đối tượng mục tiêu( class) mất cân bằng
# cho nên chúng ra cần tạo ra mẫu mới giúp cho việc cân
#bằng các dữ liệu, thuận tiện cho việc phân tích tạo mô hình
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 30, k_neighbors = 5)
X_res, y_res = sm.fit_resample(X, y)

# %%
y.value_counts()
# Out:
# 0    59445
# 2    21594
# 1    18961
# Name: class, dtype: int64

# %%
y_res.value_counts()
# Out:
# 0    59445
# 1    59445
# 2    59445
# Name: class, dtype: int64

# %% [markdown]
# ---
# ---
# <br>

# %% [markdown]
# # **Phân chia tập dữ liệu(Splitting Dataset):**

# %%
#Dùng X_res y_res thay vì X y vì tập dữ liệu ban đầu bị mất cân bằng
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.25, random_state = 30)

# %% [markdown]
# ---
# ---
# <br>

# %% [markdown]
#   # **2. Phân loại(Classification):**

# %%
# Creating the dataframe in which we'll store the accuracy
# scores of all the classification algorithms so we can choose the best one.

score_df = pd.DataFrame(columns=['Algorithm', 'Recall score'])

# %% [markdown]
# ---

# %% [markdown]
# ### **K-Nearest neighbors:**

# %%
# Now, we'll create a dataframe where we'll store the recall score of the K Neighbors Classifier algorithm with different values of n_neighbors
# Then, we'll choose the maximum one and consider that as the recall score of the KNN algo. for further use

knn_df = pd.DataFrame(columns=['Neighbors','Recall score'])

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import recall_score

for i in range(1,21):
    model = KNeighborsClassifier(n_neighbors = i)
    model.fit(X_train, y_train)
    y_pred2 = model.predict(X_test)
    knn_df = knn_df.append({'Neighbors':i,
                            'Recall score':recall_score(y_test, y_pred2,
                                                        average='weighted')},
                            ignore_index=True)

    knn_df

# %%
knn_df = knn_df.sort_values(by='Recall score', ascending = False)
knn_df.head()
# Out:
#    Neighbors  Recall score
# 0        1.0      0.931051
# 2        3.0      0.914902
# 1        2.0      0.913579
# 3        4.0      0.905616
# 4        5.0      0.903777

# %% [markdown]
# Từ đoạn mã ở trên, chúng ta có thể thấy rằng với **n_neighbors = 1** có điểm chính xác( recall_score) cao nhất trong số tất cả các giá trị trong khung dữ liệu. Vì vậy, đối với điểm chính xác cuối cùng của thuật toán KNN, chúng tôi sẽ giữ **n_neighbors = 1**.

# %%
# KNN algo for n_neighbors = 1

from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors = 1)
model.fit(X_train, y_train)
y_pred2 = model.predict(X_test)

from sklearn.metrics import recall_score
knn_score = recall_score(y_test, y_pred2, average='weighted')
print(f"Recall Score: {knn_score} ")
# Out:
# Recall Score: 0.9310514982953526

# %%
#Confusion Matrix with n_neighbor = 1
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay, classification_report
# ConfusionMatrixDisplay.from_predictions(y_test, y_pred2, cmap = 'cividis',
#                                         display_labels = ['GALAXY', 'QUASAR', 'STAR'])

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# Assuming you have your predictions in y_pred2 and actual labels in y_test
# Create the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred2)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['GALAXY', 'QUASAR', 'STAR'])
disp.plot(cmap='PuBu')
plt.title('Confusion Matrix')
plt.show()

# Calculate accuracy
rcall = recall_score(y_test, y_pred2, average = "weighted")
print(f"Recall Score: {rcall}")

# Generate classification report
class_report = classification_report(y_test, y_pred2, target_names=['GALAXY', 'QUASAR', 'STAR'])
print("Classification Report:\n", class_report)
# Out:
# Recall Score: 0.9310514982953526
# Classification Report:
#                precision    recall  f1-score   support
#
#       GALAXY       0.92      0.89      0.91     14894
#       QUASAR       0.95      0.97      0.96     14892
#         STAR       0.92      0.93      0.93     14798
#
#     accuracy                           0.93     44584
#    macro avg       0.93      0.93      0.93     44584
# weighted avg       0.93      0.93      0.93     44584

# %%
# Adding recall score of the algo to the dataframe

score_df = score_df.append({'Algorithm':'KNN', 'Recall score': knn_score}, ignore_index = True)
score_df
# Out:
#   Algorithm  Recall score
# 0       KNN      0.931051

# %% [markdown]
# ---

# %% [markdown]
# ### **Decision Tree:**

# %%
from sklearn.tree import DecisionTreeClassifier
#Khởi tạo và huấn luyện mô hình
dt_model = DecisionTreeClassifier(random_state = 30)
dt_model.fit(X_train, y_train)
#Sử dụng mô hình đã được huấn luyện để dự đoán nhãn trên tập kiểm tra(X_test)
y_pred3 = dt_model.predict(X_test)

dtree_score = recall_score(y_test, y_pred3, average='weighted')
print(f"Recall Score: {dtree_score} ")
# Out:
# Recall Score: 0.9710658532208865

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# Assuming you have your predictions in y_pred3 and actual labels in y_test
# Create the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred2)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['GALAXY', 'QUASAR', 'STAR'])
disp.plot(cmap='PuBu')
plt.title('Confusion Matrix')
plt.show()

# Calculate accuracy
rcall = recall_score(y_test, y_pred3, average = "weighted")
print(f"Recall Score: {rcall} ")

# Generate classification report
class_report = classification_report(y_test, y_pred3, target_names=['GALAXY', 'QUASAR', 'STAR'])
print("Classification Report:\n", class_report)
# Out:
# Recall Score: 0.9710658532208865
# Classification Report:
#                precision    recall  f1-score   support
#
#       GALAXY       0.96      0.95      0.96     14894
#       QUASAR       0.96      0.96      0.96     14892
#         STAR       1.00      1.00      1.00     14798
#
#     accuracy                           0.97     44584
#    macro avg       0.97      0.97      0.97     44584
# weighted avg       0.97      0.97      0.97     44584

# %%
# Visualize the Decision Tree

plt.figure(figsize=(12, 8))
plot_tree(dt_model, filled=True, feature_names=X.columns, class_names=["GALAXY", "QUASAR", "STAR"])
plt.show()

# %%
#Find the best max-depth for DT algorithm
# Define a range of max_depth values to iterate over
max_depth_values = range(3, 20)  # You can adjust this range

# Initialize variables to keep track of the best max depth and corresponding score
best_max_depth = None
best_score = 0.0

# Iterate over different max_depth values
for max_depth in max_depth_values:
    # Initialize the DecisionTreeClassifier with the current max_depth
    clf = DecisionTreeClassifier(max_depth=max_depth, random_state=42)
    # Fit the model to the training data
    clf.fit(X_train, y_train)
    # Evaluate the model on the test data
    test_score = clf.score(X_test, y_test)

    # Print the score for the current max_depth
    print(f"Max Depth = {max_depth}: Test Score = {test_score}")
    # Check if the current model has a better score than the previous best
    if test_score > best_score:
        best_score = test_score
        best_max_depth = max_depth

# Print the best max depth and corresponding score
print(f"Best Max Depth = {best_max_depth}: Best Test Score = {best_score}")
# Out:
# Max Depth = 3: Test Score = 0.9405616364615108
# Max Depth = 4: Test Score = 0.9598510676475865
# Max Depth = 5: Test Score = 0.9600305042167594
# Max Depth = 6: Test Score = 0.9689799031042526
# Max Depth = 7: Test Score = 0.9727480710568814
# Max Depth = 8: Test Score = 0.9744302888928764
# Max Depth = 9: Test Score = 0.97546204916562
# Max Depth = 10: Test Score = 0.9765162390095101
# Max Depth = 11: Test Score = 0.9767405347209761
# Max Depth = 12: Test Score = 0.9766508164363897
# Max Depth = 13: Test Score = 0.9752826125964471
# Max Depth = 14: Test Score = 0.9744975776063162
# Max Depth = 15: Test Score = 0.9742732818948502
# Max Depth = 16: Test Score = 0.974004127041091
# Max Depth = 17: Test Score = 0.9738471200430647
# Max Depth = 18: Test Score = 0.9730620850529338
# Max Depth = 19: Test Score = 0.9732639511932532
# Best Max Depth = 11: Best Test Score = 0.9767405347209761

# %%
from sklearn.tree import export_text
# Export the text representation of the decision tree
tree_rules = export_text(clf, feature_names=X.columns.tolist())
print(tree_rules)
# Out:
# |--- redshift <= 0.00
# |   |--- redshift <= -0.00
# |   |   |--- class: 0
# |   |--- redshift >  -0.00
# |   |   |--- NearInfrared_Filter <= 22.19
# |   |   |   |--- redshift <= 0.00
# |   |   |   |   |--- redshift <= -0.00
# |   |   |   |   |   |--- Green_Filter <= 27.34
# |   |   |   |   |   |   |--- redshift <= -0.00
# |   |   |   |   |   |   |   |--- redshift <= -0.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- redshift >  -0.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- redshift >  -0.00
# |   |   |   |   |   |   |   |--- Infrared_Filter <= 21.72
# |   |   |   |   |   |   |   |   |--- plate <= 11308.50
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 23.03
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 17.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  17.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  23.03
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 23.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  23.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- plate >  11308.50
# |   |   |   |   |   |   |   |   |   |--- plate <= 11309.50
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= -0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  -0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- plate >  11309.50
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 18.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  18.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- Infrared_Filter >  21.72
# |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 21.72
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Infrared_Filter >  21.72
# |   |   |   |   |   |   |   |   |   |--- redshift <= -0.00
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 22.39
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  22.39
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- redshift >  -0.00
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 21.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  21.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- Green_Filter >  27.34
# |   |   |   |   |   |   |--- Ultraviolet_Filter <= 24.01
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Ultraviolet_Filter >  24.01
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- redshift >  -0.00
# |   |   |   |   |   |--- redshift <= 0.00
# |   |   |   |   |   |   |--- NearInfrared_Filter <= 20.87
# |   |   |   |   |   |   |   |--- redshift <= -0.00
# |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 20.01
# |   |   |   |   |   |   |   |   |   |--- plate <= 688.00
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 683.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- plate >  683.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- plate >  688.00
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 25.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  25.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Infrared_Filter >  20.01
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 20.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  20.02
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- redshift >  -0.00
# |   |   |   |   |   |   |   |   |--- plate <= 5036.50
# |   |   |   |   |   |   |   |   |   |--- redshift <= -0.00
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 20.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  20.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- redshift >  -0.00
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- plate >  5036.50
# |   |   |   |   |   |   |   |   |   |--- redshift <= -0.00
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  19.95
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- redshift >  -0.00
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- NearInfrared_Filter >  20.87
# |   |   |   |   |   |   |   |--- redshift <= -0.00
# |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 20.82
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  21.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  20.82
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 25.73
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  25.73
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 21.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  21.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- redshift >  -0.00
# |   |   |   |   |   |   |   |   |--- redshift <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- redshift >  0.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- redshift >  0.00
# |   |   |   |   |   |   |--- Infrared_Filter <= 22.90
# |   |   |   |   |   |   |   |--- Infrared_Filter <= 20.81
# |   |   |   |   |   |   |   |   |--- plate <= 11081.50
# |   |   |   |   |   |   |   |   |   |--- redshift <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 14.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  14.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- redshift >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- plate >  11081.50
# |   |   |   |   |   |   |   |   |   |--- plate <= 11082.50
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 22.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  22.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- plate >  11082.50
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 20.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  20.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Infrared_Filter >  20.81
# |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 20.81
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Infrared_Filter >  20.81
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.30
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 20.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  20.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.30
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |--- Infrared_Filter >  22.90
# |   |   |   |   |   |   |   |--- Red_Filter <= 15.78
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Red_Filter >  15.78
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- redshift >  0.00
# |   |   |   |   |--- Green_Filter <= 17.95
# |   |   |   |   |   |--- plate <= 1235.00
# |   |   |   |   |   |   |--- Ultraviolet_Filter <= 18.84
# |   |   |   |   |   |   |   |--- redshift <= 0.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- redshift >  0.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- Ultraviolet_Filter >  18.84
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- plate >  1235.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Green_Filter >  17.95
# |   |   |   |   |   |--- redshift <= 0.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- redshift >  0.00
# |   |   |   |   |   |   |--- Infrared_Filter <= 22.37
# |   |   |   |   |   |   |   |--- Green_Filter <= 21.71
# |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.64
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.63
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 21.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  21.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  21.63
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 7033.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- plate >  7033.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- Red_Filter >  21.64
# |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 21.80
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  21.80
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- Green_Filter >  21.71
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- Infrared_Filter >  22.37
# |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 21.86
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- NearInfrared_Filter >  21.86
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |--- NearInfrared_Filter >  22.19
# |   |   |   |--- Infrared_Filter <= 21.48
# |   |   |   |   |--- class: 2
# |   |   |   |--- Infrared_Filter >  21.48
# |   |   |   |   |--- redshift <= 0.00
# |   |   |   |   |   |--- redshift <= -0.00
# |   |   |   |   |   |   |--- Infrared_Filter <= 21.69
# |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 23.72
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  23.72
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- Infrared_Filter >  21.69
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- redshift >  -0.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- redshift >  0.00
# |   |   |   |   |   |--- Red_Filter <= 23.65
# |   |   |   |   |   |   |--- Green_Filter <= 21.70
# |   |   |   |   |   |   |   |--- redshift <= 0.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- redshift >  0.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Green_Filter >  21.70
# |   |   |   |   |   |   |   |--- plate <= 2370.50
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 23.32
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Green_Filter >  23.32
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- plate >  2370.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- Red_Filter >  23.65
# |   |   |   |   |   |   |--- class: 0
# |--- redshift >  0.00
# |   |--- redshift <= 0.89
# |   |   |--- redshift <= 0.68
# |   |   |   |--- Infrared_Filter <= 19.94
# |   |   |   |   |--- Ultraviolet_Filter <= 21.92
# |   |   |   |   |   |--- redshift <= 0.33
# |   |   |   |   |   |   |--- redshift <= 0.19
# |   |   |   |   |   |   |   |--- plate <= 12535.50
# |   |   |   |   |   |   |   |   |--- redshift <= 0.12
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 18.03
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  18.03
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  19.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- redshift >  0.12
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 18.34
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 1160.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- plate >  1160.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  18.34
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 19.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  19.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- plate >  12535.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- redshift >  0.19
# |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 19.47
# |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 18.99
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 18.72
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 16.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  16.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  18.72
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  18.99
# |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 17.61
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 6909.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- plate >  6909.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  17.61
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 18.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  18.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  19.47
# |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 17.73
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 20.30
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  20.30
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 18.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  18.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Infrared_Filter >  17.73
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 20.03
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 19.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  19.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  20.03
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 20.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  20.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- redshift >  0.33
# |   |   |   |   |   |   |--- Ultraviolet_Filter <= 21.04
# |   |   |   |   |   |   |   |--- Green_Filter <= 20.67
# |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 20.76
# |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 24.98
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- Red_Filter >  24.98
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  20.76
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 18.81
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 20.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  20.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  18.81
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- Green_Filter >  20.67
# |   |   |   |   |   |   |   |   |--- Red_Filter <= 20.37
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Red_Filter >  20.37
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Ultraviolet_Filter >  21.04
# |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.25
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 20.93
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 18.57
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 20.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  20.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  18.57
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 2662.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- plate >  2662.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- Green_Filter >  20.93
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 21.84
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 6729.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- plate >  6729.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  21.84
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- Infrared_Filter >  19.25
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.25
# |   |   |   |   |   |   |   |   |   |--- redshift <= 0.43
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 4753.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- plate >  4753.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- redshift >  0.43
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 20.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  20.91
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- Green_Filter >  21.25
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.89
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 5577.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- plate >  5577.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  19.89
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Ultraviolet_Filter >  21.92
# |   |   |   |   |   |--- NearInfrared_Filter <= 20.74
# |   |   |   |   |   |   |--- Ultraviolet_Filter <= 23.03
# |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.38
# |   |   |   |   |   |   |   |   |--- plate <= 8769.50
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 18.54
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 19.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  19.42
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  18.54
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  21.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- plate >  8769.50
# |   |   |   |   |   |   |   |   |   |--- plate <= 8791.50
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 20.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  20.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- plate >  8791.50
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.56
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.56
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Infrared_Filter >  19.38
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.64
# |   |   |   |   |   |   |   |   |   |--- redshift <= 0.39
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.57
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  21.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- redshift >  0.39
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 20.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  20.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Green_Filter >  21.64
# |   |   |   |   |   |   |   |   |   |--- plate <= 3122.50
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.47
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  19.47
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- plate >  3122.50
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |--- Ultraviolet_Filter >  23.03
# |   |   |   |   |   |   |   |--- Red_Filter <= 21.93
# |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.51
# |   |   |   |   |   |   |   |   |   |--- redshift <= 0.25
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- redshift >  0.25
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 19.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  19.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- Infrared_Filter >  19.51
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.91
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 2266.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- plate >  2266.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  21.91
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  19.51
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- Red_Filter >  21.93
# |   |   |   |   |   |   |   |   |--- redshift <= 0.23
# |   |   |   |   |   |   |   |   |   |--- plate <= 7891.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- plate >  7891.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- redshift >  0.23
# |   |   |   |   |   |   |   |   |   |--- redshift <= 0.52
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  21.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- redshift >  0.52
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 25.39
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  25.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- NearInfrared_Filter >  20.74
# |   |   |   |   |   |   |--- redshift <= 0.52
# |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 20.80
# |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.54
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Red_Filter >  21.54
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- NearInfrared_Filter >  20.80
# |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 25.07
# |   |   |   |   |   |   |   |   |   |--- redshift <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 20.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  20.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- redshift >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  25.07
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 23.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  23.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- redshift >  0.52
# |   |   |   |   |   |   |   |--- Red_Filter <= 22.88
# |   |   |   |   |   |   |   |   |--- plate <= 11303.00
# |   |   |   |   |   |   |   |   |   |--- plate <= 7394.00
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 7354.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- plate >  7354.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- plate >  7394.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- plate >  11303.00
# |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Red_Filter >  21.84
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Red_Filter >  22.88
# |   |   |   |   |   |   |   |   |--- redshift <= 0.58
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- redshift >  0.58
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Infrared_Filter >  19.94
# |   |   |   |   |--- redshift <= 0.41
# |   |   |   |   |   |--- Red_Filter <= 21.59
# |   |   |   |   |   |   |--- plate <= 11312.50
# |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.95
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Infrared_Filter >  19.95
# |   |   |   |   |   |   |   |   |--- plate <= 6317.00
# |   |   |   |   |   |   |   |   |   |--- redshift <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 650.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- plate >  650.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- redshift >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 23.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  23.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- plate >  6317.00
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 20.79
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  20.79
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- plate >  11312.50
# |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 21.05
# |   |   |   |   |   |   |   |   |--- redshift <= 0.38
# |   |   |   |   |   |   |   |   |   |--- plate <= 11326.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- plate >  11326.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- redshift >  0.38
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- NearInfrared_Filter >  21.05
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Red_Filter >  21.59
# |   |   |   |   |   |   |--- redshift <= 0.16
# |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 25.46
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.36
# |   |   |   |   |   |   |   |   |   |--- plate <= 11322.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- plate >  11322.50
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 21.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  21.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Green_Filter >  22.36
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 24.14
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 21.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  21.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  24.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  25.46
# |   |   |   |   |   |   |   |   |--- redshift <= 0.15
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- redshift >  0.15
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- redshift >  0.16
# |   |   |   |   |   |   |   |--- Green_Filter <= 22.12
# |   |   |   |   |   |   |   |   |--- redshift <= 0.35
# |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.88
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 22.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  22.71
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Red_Filter >  21.88
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- redshift >  0.35
# |   |   |   |   |   |   |   |   |   |--- redshift <= 0.38
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- redshift >  0.38
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  21.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Green_Filter >  22.12
# |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 20.60
# |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 21.35
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 20.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  20.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  21.35
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  21.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Infrared_Filter >  20.60
# |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.92
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Red_Filter >  21.92
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 25.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  25.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- redshift >  0.41
# |   |   |   |   |   |--- Green_Filter <= 22.09
# |   |   |   |   |   |   |--- Green_Filter <= 21.42
# |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 19.85
# |   |   |   |   |   |   |   |   |--- plate <= 7249.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- plate >  7249.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- NearInfrared_Filter >  19.85
# |   |   |   |   |   |   |   |   |--- redshift <= 0.53
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 20.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  20.81
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 21.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  21.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- redshift >  0.53
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 24.05
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 20.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  20.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  24.05
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 20.93
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  20.93
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Green_Filter >  21.42
# |   |   |   |   |   |   |   |--- Red_Filter <= 21.30
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.58
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 21.93
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 10650.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- plate >  10650.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  21.93
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- Green_Filter >  21.58
# |   |   |   |   |   |   |   |   |   |--- plate <= 11211.00
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 22.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  22.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- plate >  11211.00
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 23.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  23.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Red_Filter >  21.30
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.77
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 21.54
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  21.54
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  21.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- Green_Filter >  21.77
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 24.13
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.34
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  21.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  24.13
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 21.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  21.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- Green_Filter >  22.09
# |   |   |   |   |   |   |--- NearInfrared_Filter <= 20.86
# |   |   |   |   |   |   |   |--- Red_Filter <= 22.30
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.33
# |   |   |   |   |   |   |   |   |   |--- redshift <= 0.61
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  21.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- redshift >  0.61
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 10001.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- plate >  10001.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Green_Filter >  22.33
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 22.92
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  22.92
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 23.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  23.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- Red_Filter >  22.30
# |   |   |   |   |   |   |   |   |--- Red_Filter <= 22.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Red_Filter >  22.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- NearInfrared_Filter >  20.86
# |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 22.41
# |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 21.41
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 20.04
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  20.04
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  21.54
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- Infrared_Filter >  21.41
# |   |   |   |   |   |   |   |   |   |--- plate <= 9331.00
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 9052.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- plate >  9052.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- plate >  9331.00
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- NearInfrared_Filter >  22.41
# |   |   |   |   |   |   |   |   |--- redshift <= 0.61
# |   |   |   |   |   |   |   |   |   |--- redshift <= 0.47
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 23.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  23.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- redshift >  0.47
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 17.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  17.90
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- redshift >  0.61
# |   |   |   |   |   |   |   |   |   |--- plate <= 9270.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- plate >  9270.00
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.66
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.66
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- redshift >  0.68
# |   |   |   |--- Green_Filter <= 21.80
# |   |   |   |   |--- Green_Filter <= 21.24
# |   |   |   |   |   |--- Ultraviolet_Filter <= 22.68
# |   |   |   |   |   |   |--- Ultraviolet_Filter <= 21.67
# |   |   |   |   |   |   |   |--- Green_Filter <= 20.75
# |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 22.79
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 21.25
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.26
# ...
# |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  23.18
# |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 22.22
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Red_Filter >  22.22
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 1.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  1.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- Red_Filter >  22.90
# |   |   |   |   |   |   |   |--- redshift <= 1.02
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- redshift >  1.02
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- plate >  9176.00
# |   |   |   |   |   |   |--- NearInfrared_Filter <= 21.26
# |   |   |   |   |   |   |   |--- Infrared_Filter <= 20.94
# |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.45
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Red_Filter >  21.45
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 23.45
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 9215.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- plate >  9215.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  23.45
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 23.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  23.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Infrared_Filter >  20.94
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.91
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Green_Filter >  22.91
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 23.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  23.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- NearInfrared_Filter >  21.26
# |   |   |   |   |   |   |   |--- Red_Filter <= 22.15
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.59
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Green_Filter >  22.59
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 22.64
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  22.64
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 21.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  21.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |--- Red_Filter >  22.15
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.61
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Green_Filter >  22.61
# |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 22.66
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 1.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  1.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Red_Filter >  22.66
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 22.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  22.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |--- redshift >  1.13
# |   |   |   |   |--- redshift <= 1.37
# |   |   |   |   |   |--- Red_Filter <= 22.27
# |   |   |   |   |   |   |--- plate <= 9203.50
# |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 22.15
# |   |   |   |   |   |   |   |   |--- Red_Filter <= 21.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Red_Filter >  21.50
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.51
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  22.15
# |   |   |   |   |   |   |   |   |--- redshift <= 1.37
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 18.81
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  18.81
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 22.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  22.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- redshift >  1.37
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- plate >  9203.50
# |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 21.73
# |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 22.07
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 26.74
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 9564.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- plate >  9564.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  26.74
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Infrared_Filter >  22.07
# |   |   |   |   |   |   |   |   |   |--- redshift <= 1.24
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- redshift >  1.24
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- NearInfrared_Filter >  21.73
# |   |   |   |   |   |   |   |   |--- plate <= 9572.50
# |   |   |   |   |   |   |   |   |   |--- plate <= 9322.50
# |   |   |   |   |   |   |   |   |   |   |--- redshift <= 1.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- redshift >  1.21
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- plate >  9322.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- plate >  9572.50
# |   |   |   |   |   |   |   |   |   |--- plate <= 9617.50
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 22.04
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  22.04
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- plate >  9617.50
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 22.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  22.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Red_Filter >  22.27
# |   |   |   |   |   |   |--- Ultraviolet_Filter <= 23.26
# |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 21.81
# |   |   |   |   |   |   |   |   |--- redshift <= 1.21
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 23.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  23.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- redshift >  1.21
# |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 22.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Red_Filter >  22.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- NearInfrared_Filter >  21.81
# |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 22.74
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.61
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 8994.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- plate >  8994.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.61
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Infrared_Filter >  22.74
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Ultraviolet_Filter >  23.26
# |   |   |   |   |   |   |   |--- plate <= 9195.50
# |   |   |   |   |   |   |   |   |--- Red_Filter <= 22.31
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Red_Filter >  22.31
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.73
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.54
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  19.54
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  19.73
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 23.89
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  23.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- plate >  9195.50
# |   |   |   |   |   |   |   |   |--- Green_Filter <= 23.07
# |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.54
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.54
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 9563.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- plate >  9563.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Green_Filter >  23.07
# |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 22.77
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 22.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  22.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Red_Filter >  22.77
# |   |   |   |   |   |   |   |   |   |   |--- plate <= 9607.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- plate >  9607.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- redshift >  1.37
# |   |   |   |   |   |--- redshift <= 1.67
# |   |   |   |   |   |   |--- redshift <= 1.66
# |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 24.38
# |   |   |   |   |   |   |   |   |--- Red_Filter <= 22.27
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 19.71
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 20.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  20.47
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Infrared_Filter >  19.71
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 22.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  22.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Red_Filter >  22.27
# |   |   |   |   |   |   |   |   |   |--- plate <= 7637.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- plate >  7637.00
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  24.38
# |   |   |   |   |   |   |   |   |--- Infrared_Filter <= 20.77
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 24.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  24.43
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 26.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  26.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Infrared_Filter >  20.77
# |   |   |   |   |   |   |   |   |   |--- plate <= 9372.00
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 22.59
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  22.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- plate >  9372.00
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter <= 23.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Green_Filter >  23.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- redshift >  1.66
# |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 21.84
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- NearInfrared_Filter >  21.84
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- redshift >  1.67
# |   |   |   |   |   |   |--- redshift <= 2.00
# |   |   |   |   |   |   |   |--- redshift <= 1.99
# |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 24.70
# |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 23.73
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 20.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  20.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  23.73
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter <= 24.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- NearInfrared_Filter >  24.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  24.70
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter <= 24.77
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Ultraviolet_Filter >  24.77
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter <= 23.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Red_Filter >  23.39
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- redshift >  1.99
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- redshift >  2.00
# |   |   |   |   |   |   |   |--- class: 1

# %%
from sklearn.tree import DecisionTreeClassifier
#Khởi tạo và huấn luyện mô hình
dt_model = DecisionTreeClassifier(max_depth=11, random_state = 30)
dt_model.fit(X_train, y_train)
#Sử dụng mô hình đã được huấn luyện để dự đoán nhãn trên tập kiểm tra(X_test)
y_pred3 = dt_model.predict(X_test)

dtree_score = recall_score(y_test, y_pred3, average='weighted')
print(f"Recall Score: {dtree_score} ")
# Out:
# Recall Score: 0.9767181051498295

# %%
# Adding recall score of the algo to the dataframe

score_df = score_df.append({'Algorithm':'Decision Tree', 'Recall score':dtree_score}, ignore_index = True)
score_df
# Out:
#        Algorithm  Recall score
# 0            KNN      0.931051
# 1  Decision Tree      0.976718

# %% [markdown]
# ---

# %% [markdown]
# # **Gaussian Naive Bayes**

# %%
#Khai báo thư viện GaussianNB từ sklearn.naive_bayes
from sklearn.naive_bayes import GaussianNB

#Tạo ra mô hình dữ liệu dựa trên tập dữ liệu huấn luyện đã chia
model = GaussianNB()
model.fit(X_train, y_train)

y_pred4 = model.predict(X_test)
#Kết quả dự đoán được tạo ra và đem so sánh với giá trị thực y_test
#để tìm ra độ chính xác
gnb_score = recall_score(y_test, y_pred4, average = 'weighted')
gnb_score
# Out:
# 0.6041853579759555

# %%
#Confusion Matrix
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay, classification_report
# ConfusionMatrixDisplay.from_predictions(y_test, y_pred4, cmap = 'cividis',
#                                         display_labels = ['GALAXY', 'QUASAR', 'STAR'])

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# Assuming you have your predictions in y_pred4 and actual labels in y_test
# Create the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred4)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['GALAXY', 'QUASAR', 'STAR'])
disp.plot(cmap='PuBu')
plt.title('Confusion Matrix')
plt.show()

# Calculate accuracy
rcall = recall_score(y_test, y_pred4, average = "weighted")
print(f"Recall Score: {rcall} ")

# Generate classification report
class_report = classification_report(y_test, y_pred4, target_names=['GALAXY', 'QUASAR', 'STAR'])
print("Classification Report:\n", class_report)
# Out:
# Recall Score: 0.6041853579759555
# Classification Report:
#                precision    recall  f1-score   support
#
#       GALAXY       0.50      0.84      0.63     14894
#       QUASAR       0.73      0.92      0.82     14892
#         STAR       0.74      0.05      0.09     14798
#
#     accuracy                           0.60     44584
#    macro avg       0.66      0.60      0.51     44584
# weighted avg       0.66      0.60      0.51     44584

# %%
# Adding accuracy score of the algo to the dataframe

score_df = score_df.append({'Algorithm':'GaussianNB', 'Recall score': gnb_score}, ignore_index = True)
score_df
# Out:
#        Algorithm  Recall score
# 0            KNN      0.931051
# 1  Decision Tree      0.976718
# 2     GaussianNB      0.604185

# %% [markdown]
# ---

# %% [markdown]
# ### **Random Forest(Rừng ngẫu nhiên):**

# %%
# Now, we'll create a dataframe where we'll store the recall score of the Random Forest Classifier algorithm with different values of n_estimators
# Then, we'll choose the maximum one and consider that as the recall score of the KNN algo. for further use

rf_df = pd.DataFrame(columns=['Estimators','Recall score'])

# %%
from sklearn.ensemble import RandomForestClassifier

for i in range(1,21):
    model = RandomForestClassifier(n_estimators = i, random_state = 30)
    model.fit(X_train, y_train)
    y_pred5 = model.predict(X_test)
    rf_df = rf_df.append({'Estimators':i,
            'Recall score':recall_score(y_test, y_pred5, average = 'weighted')},
            ignore_index = True)

rf_df
# Out:
#     Estimators  Recall score
# 0          1.0      0.966602
# 1          2.0      0.968374
# 2          3.0      0.977772
# 3          4.0      0.978221
# 4          5.0      0.979836
# 5          6.0      0.979970
# 6          7.0      0.980666
# 7          8.0      0.980688
# 8          9.0      0.981069
# 9         10.0      0.981316
# 10        11.0      0.981406
# 11        12.0      0.981451
# 12        13.0      0.981720
# 13        14.0      0.981810
# 14        15.0      0.981810
# 15        16.0      0.981899
# 16        17.0      0.981742
# 17        18.0      0.982011
# 18        19.0      0.981810
# 19        20.0      0.981967

# %%
rf_df = rf_df.sort_values(by='Recall score', ascending = False)
rf_df.head()
# Out:
#     Estimators  Recall score
# 17        18.0      0.982011
# 19        20.0      0.981967
# 15        16.0      0.981899
# 18        19.0      0.981810
# 14        15.0      0.981810

# %% [markdown]
# Từ đoạn mã ở trên, chúng ta có thể thấy rằng với **n_estimators = 18** có điểm thu hồi(recall_score) cao nhất trong số tất cả các giá trị trong khung dữ liệu. Vì vậy, đối với điểm thu hồi cuối cùng của thuật toán Phân loại rừng ngẫu nhiên, chúng tôi sẽ giữ **n_estimators = 18.**

# %%
# Random Forest algo for n_estimators = 18
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators = 18, random_state = 30)
model.fit(X_train, y_train)
y_pred5 = model.predict(X_test)

from sklearn.metrics import recall_score
rf_score = recall_score(y_test, y_pred5, average = 'weighted')
rf_score
# Out:
# 0.982011483940427

# %%
#Confusion Matrix
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay, classification_report
# ConfusionMatrixDisplay.from_predictions(y_test, y_pred5, cmap = 'cividis',
#                                         display_labels = ['GALAXY', 'QUASAR', 'STAR'])

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# Assuming you have your predictions in y_pred2 and actual labels in y_test
# Create the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred5)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['GALAXY', 'QUASAR', 'STAR'])
disp.plot(cmap='PuBu')
plt.title('Confusion Matrix')
plt.show()

# Calculate accuracy
rcall = recall_score(y_test, y_pred5, average = "weighted")
print(f"Recall Score: {rcall} ")

# Generate classification report
class_report = classification_report(y_test, y_pred5, target_names=['GALAXY', 'QUASAR', 'STAR'])
print("Classification Report:\n", class_report)
# Out:
# Recall Score: 0.982011483940427
# Classification Report:
#                precision    recall  f1-score   support
#
#       GALAXY       0.97      0.98      0.97     14894
#       QUASAR       0.98      0.97      0.97     14892
#         STAR       1.00      1.00      1.00     14798
#
#     accuracy                           0.98     44584
#    macro avg       0.98      0.98      0.98     44584
# weighted avg       0.98      0.98      0.98     44584

# %%
# Adding accuracy score of the algo to the dataframe

score_df = score_df.append({'Algorithm':'Random Forest', 'Recall score': rf_score}, ignore_index = True)
score_df
# Out:
#        Algorithm  Recall score
# 0            KNN      0.931051
# 1  Decision Tree      0.976718
# 2     GaussianNB      0.604185
# 3  Random Forest      0.982011

# %% [markdown]
# ---

# %% [markdown]
# # **Mô hình có hiệu suất cao nhất**

# %%
score_df = score_df.set_index('Recall score')
score_df
# Out:
#                   Algorithm
# Recall score
# 0.931051                KNN
# 0.976718      Decision Tree
# 0.604185         GaussianNB
# 0.982011      Random Forest

# %%
score_df = score_df.sort_values(by = 'Recall score', ascending = False)
score_df
# Out:
#                   Algorithm
# Recall score
# 0.982011      Random Forest
# 0.976718      Decision Tree
# 0.931051                KNN
# 0.604185         GaussianNB

# %% [markdown]
# Sau khi phân tích và đánh giá cẩn thận các mô hình khác nhau, thuật toán **Random Forest** nổi lên là mô hình hoạt động tốt nhất về độ chính xác và hiệu suất dự đoán. Vì vậy, tôi đã quyết định sử dụng bộ phân loại **Random Forest** để huấn luyện mô hình của mình.

# %% [markdown]
# ---

# %% [markdown]
# # **Tính năng quan trọng:**

# %%
feature_names = ['Ultraviolet_Filter',
                 'Green_Filter',
                 'Red_Filter',
                 'NearInfrared_Filter',
                 'Infrared_Filter',
                 'redshift',
                 'plate']
feature_importances = model.feature_importances_

f, ax = plt.subplots(figsize=(10, 7))
ax.barh(range(len(feature_importances)),
        feature_importances,
        color='midnightblue',
        alpha=.7)
ax.set_yticks(range(len(feature_importances)))
ax.set_yticklabels(feature_names)
ax.set_title("Importance of each feature")
ax.set_xlabel("Importance")
plt.show()

# %% [markdown]
# Dựa vào biểu đồ trên, giá trị **redshift** là tính năng vượt trội về tầm quan trọng, tiếp theo là **Infrared_ilter** và **Green_Filter**

# %% [markdown]
# ---

# %% [markdown]
# # **Huấn luyện với mô hình tốt nhất và siêu tham số:**

# %%
#Tạo và huấn luyện mô hình với thuật toán có hiệu suất hoạt động tốt nhất
#trên tập huấn luyện (Random Forest) để thực hiện trên hệ số n_estimators tốt nhất
model = RandomForestClassifier(n_estimators=18, max_depth=None)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=18)

# %% [markdown]
# # **Tạo dự đoán:**

# %%
#Dự đoán trên tập dữ liệu kiểm thử
prediction = model.predict(X_test)

# %% [markdown]
# # **Classification Report:**
# Xác định hiệu suất của mô hình bằng cách sử dụng một số
# số liệu đánh giá hiệu suất(accuracy, precision, recall, f1_score, support).

# %%
#Xuất ra màn hình bảng đánh giá hiệu suất của mô hình
report = classification_report(y_test, prediction, digits=5)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0    0.96449   0.97932   0.97185     14894
#            1    0.98148   0.96421   0.97277     14892
#            2    0.99751   0.99973   0.99862     14798
#
#     accuracy                        0.98105     44584
#    macro avg    0.98116   0.98109   0.98108     44584
# weighted avg    0.98112   0.98105   0.98104     44584

# %% [markdown]
# # **Confusion Matrix:**

# %%
ConfusionMatrixDisplay.from_predictions(y_test, prediction, cmap = 'PuBu',
                                        display_labels = ['GALAXY', 'QUASAR', 'STAR'])

# %% [markdown]
# Sau quá trình phân loại thì Random Forest là thuật toán phù hợp nhất với bài toán Stellar Classification và redshift là thuộc tính quan trọng, ảnh hưởng trực tiếp đến kết quả phân loại.

# %% [markdown]
# ---
